# %%
from datapackage import Package
import pandas as pd

package = Package('https://datahub.io/sports-data/english-premier-league/datapackage.json')

# print list of all resources:
print(package.resource_names)

season = '1819'

season_name = 'season-' + season + '_csv'



# print processed tabular data (if exists any)
for resource in [package.resources[idx]]:
    if resource.descriptor['datahub']['type'] == 'derived/csv':
        resource = resource.read()
# Out:
# ['validation_report', 'season-1819_csv', 'season-1718_csv', 'season-1617_csv', 'season-1516_csv', 'season-1415_csv', 'season-1314_csv', 'season-1213_csv', 'season-1112_csv', 'season-1011_csv', 'season-0910_csv', 'season-1819_json', 'season-1718_json', 'season-1617_json', 'season-1516_json', 'season-1415_json', 'season-1314_json', 'season-1213_json', 'season-1112_json', 'season-1011_json', 'season-0910_json', 'english-premier-league_zip', 'season-1819', 'season-1718', 'season-1617', 'season-1516', 'season-1415', 'season-1314', 'season-1213', 'season-1112', 'season-1011', 'season-0910']

# %%
idx
# Out:
# 1

# %%
package.resources[idx]

# %%
idx = np.where(np.array(package.resource_names) == season_name)[0][0]

# %%
import numpy as np

# %%
pd.DataFrame(resource)
# Out:
#              0               1               2   3   4  5   6   7  8   \
# 0    2018-08-10      Man United       Leicester   2   1  H   1   0  H
# 1    2018-08-11     Bournemouth         Cardiff   2   0  H   1   0  H
# 2    2018-08-11          Fulham  Crystal Palace   0   2  A   0   1  A
# 3    2018-08-11    Huddersfield         Chelsea   0   3  A   0   2  A
# 4    2018-08-11       Newcastle       Tottenham   1   2  A   1   2  A
# 5    2018-08-11         Watford        Brighton   2   0  H   1   0  H
# 6    2018-08-11          Wolves         Everton   2   2  D   1   1  D
# 7    2018-08-12         Arsenal        Man City   0   2  A   0   1  A
# 8    2018-08-12       Liverpool        West Ham   4   0  H   2   0  H
# 9    2018-08-12     Southampton         Burnley   0   0  D   0   0  D
# 10   2018-08-18         Cardiff       Newcastle   0   0  D   0   0  D
# 11   2018-08-18         Chelsea         Arsenal   3   2  H   2   2  D
# ...

# %%
resource
# Out:
# [[datetime.date(2018, 8, 10),
#   'Man United',
#   'Leicester',
#   2,
#   1,
#   'H',
#   1,
#   0,
#   'H',
#   'A Marriner',
#   8,
#   13,
#   6,
#   4,
#   11,
#   8,
#   2,
#   5,
#   2,
#   1,
#   0,
#   0],
#  [datetime.date(2018, 8, 11),
#   'Bournemouth',
#   'Cardiff',
#   2,
#   0,
#   'H',
#   1,
#   0,
#   'H',
#   'K Friend',
#   12,
#   10,
#   4,
#   1,
#   11,
#   9,
#   7,
#   4,
#   1,
#   1,
#   0,
#   0],
#  [datetime.date(2018, 8, 11),
#   'Fulham',
#   'Crystal Palace',
#   0,
#   2,
#   'A',
#   0,
#   1,
#   'A',
#   'M Dean',
#   15,
#   10,
#   6,
#   9,
#   9,
#   11,
#   5,
#   5,
#   1,
#   2,
#   0,
#   0],
#  [datetime.date(2018, 8, 11),
#   'Huddersfield',
#   'Chelsea',
#   0,
#   3,
#   'A',
#   0,
#   2,
#   'A',
#   'C Kavanagh',
#   6,
#   13,
#   1,
#   4,
#   9,
#   8,
#   2,
#   5,
#   2,
#   1,
#   0,
#   0],
#  [datetime.date(2018, 8, 11),
#   'Newcastle',
#   'Tottenham',
#   1,
#   2,
#   'A',
#   1,
#   2,
#   'A',
#   'M Atkinson',
# ...
